# %%
    import numpy as np
    import pandas as pd
    import os
    import xarray as xr
    from datetime import datetime, timedelta

# %%
file_old = r"C:\Users\alleh\Documents\+Uni_Innsbruck\+MasterThesis\data\PPL\ramanlidar_10s.nc"
ds_old = xr.open_dataset(file_old)
ds_old = ds_old.sortby("time")
ds_old = ds_old.sel(time=slice("2024-08-23T00:00:00", None))
ds_old
# Out:
# <xarray.Dataset> Size: 9GB
# Dimensions:                           (height: 3201, time: 137659)
# Coordinates:
#   * height                            (height) float32 13kB 0.0 3.75 ... 1.2e+04
#   * time                              (time) datetime64[ns] 1MB 2024-08-23T00...
# Data variables:
#     wvmr                              (height, time) float32 2GB ...
#     br                                (height, time) float32 2GB ...
#     bsc                               (height, time) float32 2GB ...
#     temp                              (time, height) float64 4GB ...
#     Latitude                          float32 4B ...
#     Longitude                         float32 4B ...
#     Averaged_laser_pulses             float32 4B ...
#     Height_above_ground_level         float32 4B ...
#     Range_resolution                  float32 4B ...
#     Elevation                         float32 4B ...
#     Azimuth                           float32 4B ...
# ...

# %%
#ds_old.Azimuth.values                           # 35
#ds_old.Elevation.values                         # 86.6
# ds_old.Height_above_ground_level.values        # 574 m ASL
# ds_old.Laser_pulse_repetition_frequency.values # 200
# ds_old.Range_resolution.values                 # 3.75 m
# ds_old.Longitude.values                        # 14.122507°
# ds_old.Latitude.values                         # 52.208683°
# Out:
# array(200., dtype=float32)

# %%
file = r"C:\Users\alleh\Documents\+Uni_Innsbruck\+MasterThesis\data\PPL\PPL_1200s_gl97m.nc"
ds = xr.open_dataset(file)
ds
# Out:
# <xarray.Dataset> Size: 44MB
# Dimensions:  (time: 1154, height: 3200)
# Coordinates:
#   * time     (time) datetime64[ns] 9kB 2024-08-23T00:20:40 ... 2024-09-08T23:...
#   * height   (height) float64 26kB 3.75 7.5 11.25 ... 1.199e+04 1.2e+04 1.2e+04
# Data variables:
#     wvmr     (time, height) float32 15MB ...
#     temp     (time, height) float32 15MB ...
#     br       (time, height) float32 15MB ...
# Attributes:
#     timestep:          1200s
#     resolution_range:  3.75
#     gliding_h_mean:    Gliding mean with a window of 97.5 m (26 bins)
#     latitude:          52.208683
#     longitude:         14.122507
#     GPS_altitude_asl:  574.0
#     gate:              3200.0
#     title:             Purple Pulse Lidar Data in 1200s steps

# %%
# ds_old.Height_above_ground_level.values        # 574 m ASL
# ds_old.Laser_pulse_repetition_frequency.values # 200
# ds_old.Range_resolution.values                 # 3.75 m
# ds_old.Longitude.values                        # 14.122507°
# ds_old.Latitude.values                         # 52.208683°
